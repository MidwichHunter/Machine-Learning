# %% [markdown]
# # Лабораторная работа №4, вариант 10

# %% [markdown]
# ### Цель работы: изучение принципов решения задачи многомерной регрессии с использованием методов машинного обучения.

# %% [markdown]
# #### Вариант 10 – Получение азотной кислоты
#
# Датасет – x10.csv

# %% [markdown]
# На химическом заводе по окислению аммиака в азотную кислоту измерения проводились каждый день. Имеется 21 строка данных.

# %% [markdown]
# Атрибуты:
#
# • I – индекс;
#
# • A1 – время работы,
#
# • A2 – температура охлаждающей жидкости,
#
# • A3 – концентрация преобразованной кислоты.
#
# • B – процентное содержание необработанного аммиака.

# %% [markdown]
# **1. Импортируйте необходимые библиотеки и загружаем данные**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('x10.csv')
df.head()
# Out:
#    Number  OperationTime  CoolantTemperature  TransformedAcidConcentration  \
# 0       1             80                  27                            89
# 1       2             80                  27                            88
# 2       3             75                  25                            90
# 3       4             62                  24                            87
# 4       5             62                  22                            87
#
#    UnprocessedPercentage
# 0                     42
# 1                     37
# 2                     37
# 3                     28
# 4                     18

# %%
Удалим признак Number, из-за отсутствия логического и смыслового содержания

# %%
df = df.drop('Number', axis=1)

# %% [markdown]
# **2. Получим информацию о датасете**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 4 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   OperationTime                 21 non-null     int64
#  1   CoolantTemperature            21 non-null     int64
#  2   TransformedAcidConcentration  21 non-null     int64
#  3   UnprocessedPercentage         21 non-null     int64
# dtypes: int64(4)
# memory usage: 804.0 bytes

# %% [markdown]
# **3. Проверяем наличие пропущенных значений и выбросов**

# %%
print(df.isnull().sum())
# Out:
# OperationTime                   0
# CoolantTemperature              0
# TransformedAcidConcentration    0
# UnprocessedPercentage           0
# dtype: int64

# %% [markdown]
# Пропущенные значения отсутствуют, следовательно пропускаем пункт с заполнением пропусков.

# %% [markdown]
# **3. Исключаем невлияющие категориальные признаки**

# %% [markdown]
# В нашем случае нет необходимости удалять категориальные признаки, так как все признаки являются количественными.

# %% [markdown]
# **4. Разделяем данные на признаки и целевую перемнную**

# %%
df_copy = df.copy()

y = df_copy['UnprocessedPercentage']
X = df_copy.drop('UnprocessedPercentage', axis=1)

type(X), type(y)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.series.Series)

# %%
print("Целевая переменная (y):")
print(y.head())

print("\nПризнаки (X):")
print(X.head())
# Out:
# Целевая переменная (y):
# 0    42
# 1    37
# 2    37
# 3    28
# 4    18
# Name: UnprocessedPercentage, dtype: int64
#
# Признаки (X):
#    OperationTime  CoolantTemperature  TransformedAcidConcentration
# 0             80                  27                            89
# 1             80                  27                            88
# 2             75                  25                            90
# 3             62                  24                            87
# 4             62                  22                            87

# %% [markdown]
# **5. Разделяем данные на обучающую и тестовую выборку**

# %%
from sklearn.model_selection import train_test_split

#Данные разделены в соотношении 75/25 (25% - для тестирования)
X_train, X_test, y_train, y_test = train_test_split(X, y , test_size=0.25, random_state=0)

# %% [markdown]
# **6. Применяем операцию нормализации для численной устойчивости**

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

scaler = StandardScaler()
scaler
# Out:
# StandardScaler()

# %% [markdown]
# **7. Масштабируем признаки обучающей выборки**

# %%
X_train_scaled = scaler.fit_transform(X_train)

scaler.mean_, scaler.scale_
# Out:
# (array([59.13333333, 21.26666667, 85.06666667]),
#  array([8.78534133, 2.93181779, 5.6031737 ]))

# %% [markdown]
# **8. Обучаем модель линейной регресии**

# %%
model = LinearRegression().fit(X_train_scaled, y_train)
model
# Out:
# LinearRegression()

# %% [markdown]
# **9. Делаем прогноз на основе данных тестирования**

# %%
X_test_scaled = scaler.transform(X_test)

y_pred = model.predict(X_test_scaled)
y_pred[:5]
# Out:
# array([18.03231875, 12.8722084 , 24.84256839, 41.60533674, 11.4721466 ])

# %%
from sklearn.metrics import root_mean_squared_error

# сравним тестовые и прогнозные значения
print('Root Mean Squared Error (RMSE):', root_mean_squared_error(y_test, y_pred))
# Out:
# Root Mean Squared Error (RMSE): 4.70737716567199

# %% [markdown]
# Root Mean Squared Error (RMSE) показывает среднюю величину ошибки предсказания в абсолютных единицах. 5.457 тысяч - это средняя ошибка модели при предсказании стоимости дома.

# %%
from sklearn.metrics import r2_score
print('R2:', np.round(r2_score(y_test, y_pred), 2))
# Out:
# R2: 0.71

# %% [markdown]
# R2 (коэффициент детерминации) показывает, какая доля дисперсии целевой переменной объясняется моделью.
#
#
# 0.71 = 71% — модель объясняет 71% изменчивости доли необработанного продукта. 29% изменчивости обусловлено факторами, не учтенными в модели.

# %%
model.score(X_test_scaled, y_test)
# Out:
# 0.7080020526808045

# %% [markdown]
# **10. Итоговое уравнение**

# %% [markdown]
# ![ИтоговоеУравнение.png](attachment:b72d5fa6-4c27-48ba-860a-78f2f7e430e8.png)

# %%
print ('Coefficients: ', model.coef_)
# Out:
# Coefficients:  [ 7.7652042   3.13346479 -0.82646348]

# %%
print ('Intercept: ', model.intercept_)
# Out:
# Intercept:  17.466666666666665

# %% [markdown]
# **11. Оценим влияние признаков на целевую переменную**

# %% [markdown]
# Пропускаем этап заполнения пропусков и изменения категориальных признаков на исходном датасете, потому что для нашего варианта это не требуется

# %%
df.corr()
# Out:
#                               OperationTime  CoolantTemperature  \
# OperationTime                      1.000000            0.781852
# CoolantTemperature                 0.781852            1.000000
# TransformedAcidConcentration       0.500143            0.390940
# UnprocessedPercentage              0.919663            0.875504
#
#                               TransformedAcidConcentration  \
# OperationTime                                     0.500143
# CoolantTemperature                                0.390940
# TransformedAcidConcentration                      1.000000
# UnprocessedPercentage                             0.399830
#
#                               UnprocessedPercentage
# OperationTime                              0.919663
# CoolantTemperature                         0.875504
# TransformedAcidConcentration               0.399830
# UnprocessedPercentage                      1.000000

# %% [markdown]
# Сильнейшие положительные корреляции:
#
# OperationTime = 0.919663 — длительность операции сильно коррелирует с долей необработанного продукта
#
# CoolantTemperature = 0.875504 — температура охлаждающей жидкости заметно связана с конечным результатом
#
# TransformedAcidConcentration = 0.399830 — концентрация кислоты имеет умеренную положительную связь

# %% [markdown]
# Сильнейшие отрицательные корреляции:
#
#
# В данном наборе данных сильных отрицательных корреляций не выявлено

# %% [markdown]
# **12.Визуализация результатов регресии**

# %%
plt.figure(figsize=(7, 5))
plt.scatter(y_test, y_pred, alpha=0.5)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')
plt.xlabel("Фактические значения")
plt.ylabel("Предсказанные значения")
plt.title("Фактические vs Предсказанные значения")
plt. grid()
plt.show()

# %% [markdown]
# Модель хорошо предсказывает в среднем диапазоне (10-30%), но занижает высокие значения (>35%) и завышает низкие (<10%). Это говорит о нелинейной зависимости в процессе.

# %% [markdown]
# **13.Остатки регресии**

# %%
residuals = y_test - y_pred
plt.figure(figsize=(10, 6))
plt.scatter(y_pred, residuals, alpha=0.7)
plt.axhline(y=0, color='red', linestyle='--', linewidth=2, label='Нет ошибки')
plt.xlabel('Предсказанные значения (Predicted)')
plt.ylabel('Остатки (Residuals)')
plt.title('Диаграмма остатков (Residuals Plot)')
plt. legend()
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# Остатки показывают систематическую ошибку: отрицательные при низких значениях и положительные при высоких. Модель стабильно ошибается на экстремальных точках — нужно учитывать нелинейные эффекты.
